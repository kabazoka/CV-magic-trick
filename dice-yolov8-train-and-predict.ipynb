# %% [markdown]
# # Dice YOLOv8 Train and Predict

# %%
#!rm -rf

# %%
# %pip install wandb==0.15.0
# !wandb --version
# Out:
# Collecting wandb==0.15.0
#   Downloading wandb-0.15.0-py3-none-any.whl (2.0 MB)
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#      ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#       --------------------------------------- 0.0/2.0 MB 262.6 kB/s eta 0:00:08
#      - -------------------------------------- 0.1/2.0 MB 409.6 kB/s eta 0:00:05
#      -- ------------------------------------- 0.1/2.0 MB 595.3 kB/s eta 0:00:04
#      ---- ----------------------------------- 0.2/2.0 MB 981.9 kB/s eta 0:00:02
#      ------- -------------------------------- 0.4/2.0 MB 1.4 MB/s eta 0:00:02
#      ----------- ---------------------------- 0.6/2.0 MB 1.8 MB/s eta 0:00:01
#      ---------------- ----------------------- 0.8/2.0 MB 2.3 MB/s eta 0:00:01
#      --------------------- ------------------ 1.1/2.0 MB 2.8 MB/s eta 0:00:01
#      ------------------------ --------------- 1.2/2.0 MB 2.7 MB/s eta 0:00:01
#      -------------------------------- ------- 1.6/2.0 MB 3.2 MB/s eta 0:00:01
#      ---------------------------------------  2.0/2.0 MB 3.7 MB/s eta 0:00:01
#      ---------------------------------------- 2.0/2.0 MB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from wandb==0.15.0) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb==0.15.0)
#   Obtaining dependency information for GitPython!=3.1.29,>=1.0.0 from https://files.pythonhosted.org/packages/8d/c4/82b858fb6483dfb5e338123c154d19c043305b01726a67d89532b8f8f01b/GitPython-3.1.40-py3-none-any.whl.metadata
#   Downloading GitPython-3.1.40-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from wandb==0.15.0) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from wandb==0.15.0) (5.9.0)
# Collecting sentry-sdk>=1.0.0 (from wandb==0.15.0)
#   Obtaining dependency information for sentry-sdk>=1.0.0 from https://files.pythonhosted.org/packages/63/25/d22e1e152e4eac10d39d9132d7b5f1ea4bdfa0b9a1d65fc606a7b90aeefb/sentry_sdk-1.32.0-py2.py3-none-any.whl.metadata
#   Downloading sentry_sdk-1.32.0-py2.py3-none-any.whl.metadata (9.8 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb==0.15.0)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: PyYAML in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from wandb==0.15.0) (6.0.1)
# Collecting pathtools (from wandb==0.15.0)
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting setproctitle (from wandb==0.15.0)
#   Obtaining dependency information for setproctitle from https://files.pythonhosted.org/packages/7e/ba/f6da9ba74e8c2c662e932b27a01025c1bee2846222f6a2e87a69c259772f/setproctitle-1.3.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading setproctitle-1.3.3-cp311-cp311-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: setuptools in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from wandb==0.15.0) (68.0.0)
# Collecting appdirs>=1.4.3 (from wandb==0.15.0)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from wandb==0.15.0) (3.20.3)
# Requirement already satisfied: colorama in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from Click!=8.0.0,>=7.0->wandb==0.15.0) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from docker-pycreds>=0.4.0->wandb==0.15.0) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb==0.15.0)
#   Obtaining dependency information for gitdb<5,>=4.0.1 from https://files.pythonhosted.org/packages/fd/5b/8f0c4a5bb9fd491c277c21eff7ccae71b47d43c4446c9d0c6cff2fe8c2c4/gitdb-4.0.11-py3-none-any.whl.metadata
#   Downloading gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from requests<3,>=2.0.0->wandb==0.15.0) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from requests<3,>=2.0.0->wandb==0.15.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from requests<3,>=2.0.0->wandb==0.15.0) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from requests<3,>=2.0.0->wandb==0.15.0) (2023.7.22)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb==0.15.0)
#   Obtaining dependency information for smmap<6,>=3.0.1 from https://files.pythonhosted.org/packages/a7/a5/10f97f73544edcdef54409f1d839f6049a0d79df68adbc1ceb24d1aaca42/smmap-5.0.1-py3-none-any.whl.metadata
#   Downloading smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#    ---------------------------------------- 0.0/190.6 kB ? eta -:--:--
#    --------------------------------------- 190.6/190.6 kB 12.0 MB/s eta 0:00:00
# Downloading sentry_sdk-1.32.0-py2.py3-none-any.whl (240 kB)
#    ---------------------------------------- 0.0/241.0 kB ? eta -:--:--
#    ---------------------------------------- 241.0/241.0 kB 4.9 MB/s eta 0:00:00
# Downloading setproctitle-1.3.3-cp311-cp311-win_amd64.whl (11 kB)
# Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#    ---------------------------------------- 0.0/62.7 kB ? eta -:--:--
#    ---------------------------------------- 62.7/62.7 kB ? eta 0:00:00
# Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py): started
#   Building wheel for pathtools (setup.py): finished with status 'done'
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8802 sha256=07d69d4333be4a4ad59eb394de03c89ce01670979b0c7644b7aa5f8d9ad5261d
#   Stored in directory: c:\users\kabaz_kwuenmy\appdata\local\pip\cache\wheels\ea\b7\8b\84e94095ea418b9442f5abeba4ca7b0ad52d3fe7b69d6238a6
# Successfully built pathtools
# Installing collected packages: pathtools, appdirs, smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, GitPython, wandb
# Successfully installed GitPython-3.1.40 appdirs-1.4.4 docker-pycreds-0.4.0 gitdb-4.0.11 pathtools-0.1.2 sentry-sdk-1.32.0 setproctitle-1.3.3 smmap-5.0.1 wandb-0.15.0
# Note: you may need to restart the kernel to use updated packages.
# wandb, version 0.15.0

# %%
# %pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (8.0.199)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (3.8.0)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (1.26.1)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\kabaz_kwuenmy\appdata\roaming\python\python311\site-packages (from ultralytics) (4.8.1.78)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (10.1.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (1.11.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (2.1.0+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (0.16.0+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (4.66.1)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (2.1.1)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (0.13.0)
# Requirement already satisfied: psutil in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: py-cpuinfo in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: thop>=0.1.1 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from pandas>=1.1.4->ultralytics) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from requests>=2.23.0->ultralytics) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from requests>=2.23.0->ultralytics) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from requests>=2.23.0->ultralytics) (2023.7.22)
# Requirement already satisfied: filelock in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from torch>=1.8.0->ultralytics) (3.12.4)
# Requirement already satisfied: typing-extensions in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from torch>=1.8.0->ultralytics) (4.8.0)
# Requirement already satisfied: sympy in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from torch>=1.8.0->ultralytics) (1.12)
# Requirement already satisfied: networkx in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from torch>=1.8.0->ultralytics) (2023.6.0)
# Requirement already satisfied: colorama in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\kabaz_kwuenmy\.conda\envs\yolov8\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import cv2
import random
import numpy as np
import pandas as pd
from tqdm import tqdm
import shutil
from shutil import copyfile
import matplotlib.pyplot as plt
from matplotlib import animation, rc
rc('animation', html='jshtml')
from PIL import Image
import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.199  Python-3.11.5 torch-2.1.0+cu121 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
# Setup complete  (8 CPUs, 31.9 GB RAM, 266.5/464.6 GB disk)

# %%
# Wandb login:
# %pip install kaggle_secrets
from kaggle_secrets import UserSecretsClient
import wandb
user_secrets = UserSecretsClient()
secret_value = user_secrets.get_secret("wandb_api_key")
wandb.login(key=secret_value)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\kabaz_kwuenmy\Documents\GitHub\cv-magic-trick\dice-yolov8-train-and-predict.ipynb 儲存格 6 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/kabaz_kwuenmy/Documents/GitHub/cv-magic-trick/dice-yolov8-train-and-predict.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # Wandb login:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kabaz_kwuenmy/Documents/GitHub/cv-magic-trick/dice-yolov8-train-and-predict.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> from kaggle_secrets import UserSecretsClient
#       <a href='vscode-notebook-cell:/c%3A/Users/kabaz_kwuenmy/Documents/GitHub/cv-magic-trick/dice-yolov8-train-and-predict.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> import wandb
#       <a href='vscode-notebook-cell:/c%3A/Users/kabaz_kwuenmy/Documents/GitHub/cv-magic-trick/dice-yolov8-train-and-predict.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> user_secrets = UserSecretsClient()
#
# ModuleNotFoundError: No module named 'kaggle_secrets'

# %%
# !mkdir datasets
# !mkdir datasets/train
# !mkdir datasets/valid
# !mkdir datasets/test
# !mkdir datasets/train/images
# !mkdir datasets/valid/images
# !mkdir datasets/test/images
# !mkdir datasets/train/labels
# !mkdir datasets/valid/labels
# !mkdir datasets/test/labels

train_path='datasets/train/'
valid_path='datasets/valid/'
test_path='datasets/test/'

# %% [markdown]
# # Data Preparation

# %%
ano_paths=[]
for dirname, _, filenames in os.walk('C:/Users/kabaz_kwuenmy/Documents/GitHub/cv-magic-trick/d6-dice-dataset/Annotations'):
    for filename in filenames:
        if filename[-4:]=='.txt':
            ano_paths+=[(os.path.join(dirname, filename))]
        
n=len(ano_paths) 
print(n)
N=list(range(n))
random.shuffle(N)

train_ratio = 0.6
valid_ratio = 0.2
test_ratio = 0.2

train_size = int(train_ratio*n)
valid_size = int(valid_ratio*n)

train_i = N[:train_size]
valid_i = N[train_size:train_size+valid_size]
test_i = N[train_size+valid_size:]

#print(train_i)
#print(valid_i)
#print(test_i)

# %%
for i in train_i:
    ano_path=ano_paths[i]
    img_path=os.path.join('C:/Users/kabaz_kwuenmy/Documents/GitHub/cv-magic-trick/d6-dice-dataset/Images',
                          ano_path.split('/')[-1][0:-4]+'.jpg')
    try:
        # !cp {ano_path} {train_path}
        # !cp {img_path} {train_path}
    except:
        continue
print(len(os.listdir(train_path)))

# %%
for i in valid_i:
    ano_path=ano_paths[i]
    img_path=os.path.join('C:/Users/kabaz_kwuenmy/Documents/GitHub/cv-magic-trick/d6-dice-dataset/Images',
                          ano_path.split('/')[-1][0:-4]+'.jpg')
    try:
        # !cp {ano_path} {valid_path}
        # !cp {img_path} {valid_path}
    except:
        continue
print(len(os.listdir(valid_path)))

# %%
for i in test_i:
    ano_path=ano_paths[i]
    img_path=os.path.join('C:/Users/kabaz_kwuenmy/Documents/GitHub/cv-magic-trick/d6-dice-dataset/Images',
                          ano_path.split('/')[-1][0:-4]+'.jpg')
    try:
        # !cp {ano_path} {test_path}
        # !cp {img_path} {test_path}
    except:
        continue
print(len(os.listdir(test_path)))

# %% [markdown]
# # Create yaml file

# %%
import yaml

data_yaml = dict(
    train ='train',
    val ='valid',
    test='test',
    nc =6,
    names =list('123456')
)

with open('data.yaml', 'w') as outfile:
    yaml.dump(data_yaml, outfile, default_flow_style=True)
    
# %cat data.yaml

# %%
names =list('123456')
M=list(range(len(names)))
class_map=dict(zip(M,names))

# %% [markdown]
# # Train

# %%
model = YOLO("yolov8x.pt")

# %%
# !yolo task=detect mode=train model=yolov8x.pt data=data.yaml epochs=12 imgsz=480

# %% [markdown]
# # Result of Training

# %%
paths2=[]
for dirname, _, filenames in os.walk('C:/Users/kabaz_kwuenmy/Documents/GitHub/cv-magic-trick/train'):
    for filename in filenames:
        if filename[-4:]=='.jpg':
            paths2+=[(os.path.join(dirname, filename))]
paths2=sorted(paths2)

# %%
for path in paths2:
    image = Image.open(path)
    image=np.array(image)
    plt.figure(figsize=(20,10))
    plt.imshow(image)
    plt.show()

# %% [markdown]
# # Predict

# %%
best_path0='runs/detect/train/weights/best.pt'
source0='datasets/test'

# %%
ppaths=[]
for dirname, _, filenames in os.walk(source0):
    for filename in filenames:
        if filename[-4:]=='.jpg':
            ppaths+=[(os.path.join(dirname, filename))]
ppaths=sorted(ppaths)
print(ppaths[0])
print(len(ppaths))

# %%
model2 = YOLO(best_path0)

# %%
# !yolo task=detect mode=predict model={best_path0} conf=0.2 source={source0}

# %% [markdown]
# # Result of Prediction

# %%
results = model2.predict(source0,conf=0.2)
print(len(results))

# %%
print((results[0].boxes.data))

# %%
PBOX=pd.DataFrame(columns=range(6))
for i in range(len(results)):
    arri=pd.DataFrame(results[i].boxes.data.cpu().numpy()).astype(float)
    path=ppaths[i]
    file=path.split('/')[-1]
    arri=arri.assign(file=file)
    arri=arri.assign(i=i)
    PBOX=pd.concat([PBOX,arri],axis=0)
PBOX.columns=['x','y','x2','y2','confidence','class','file','i']
display(PBOX)

# %%
PBOX['class']=PBOX['class'].apply(lambda x: class_map[int(x)])
PBOX=PBOX.reset_index(drop=True)
display(PBOX)
display(PBOX['class'].value_counts())

# %%
def draw_box2(n0):
    
    ipath=ppaths[n0]
    image=cv2.imread(ipath)
    H,W=image.shape[0],image.shape[1]
    file=ipath.split('/')[-1]  
    
    if PBOX[PBOX['file']==file] is not None:
        box=PBOX[PBOX['file']==file]
        box=box.reset_index(drop=True)
        #display(box)
        for i in range(len(box)):
            label=box.loc[i,'class']
            x=int(box.loc[i,'x'])
            y=int(box.loc[i,'y'])
            x2=int(box.loc[i,'x2']) 
            y2=int(box.loc[i,'y2'])
            #print(label,x,y,x2,y2)
            cv2.putText(image, f'{label}', (x,int(y-4)), 
                        cv2.FONT_HERSHEY_SIMPLEX, 4.0,(0,255,0),3)
            cv2.rectangle(image,(x,y),(x2,y2),(0,255,0),3)
            
    return image

# %%
def create_animation(ims):
    fig=plt.figure(figsize=(12,8))
    im=plt.imshow(cv2.cvtColor(ims[0],cv2.COLOR_BGR2RGB))
    text = plt.text(0.05, 0.05, f'Slide {0}', transform=fig.transFigure, fontsize=14, color='blue')
    plt.axis('off')
    plt.close()

    def animate_func(i):
        im.set_array(cv2.cvtColor(ims[i],cv2.COLOR_BGR2RGB))
        text.set_text(f'Slide {i}')        
        return [im]    
    
    return animation.FuncAnimation(fig, animate_func, frames=len(ims), interval=1000)

# %%
images2=[]
for i in tqdm(range(len(ppaths))):
    images2+=[draw_box2(i)]

# %%
create_animation(images2)
